# %%
#Importing necessary libraries 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %%
#reasding dataset
df = pd.read_csv('Social_Network_Ads.csv')

# %%
# Assuming 'Age' and 'EstimatedSalary', as our features and 'Purchased' as the target variable
X = df[['Age', 'EstimatedSalary']]
y = df['Purchased']

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Feature scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Logistic Regression model
classifier = LogisticRegression(random_state=42)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Predicting the test set results
y_pred = classifier.predict(X_test)

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[61  2]
#  [12 25]]

# %%
# Calculating TP, FP, TN, FN
TP = cm[1, 1]
FP = cm[0, 1]
TN = cm[0, 0]
FN = cm[1, 0]

# %%
print('True Positives =', TP, ',', 'False Positives =', FP, ',', 'True Negatives =', TN, ',', 'False Negatives =', FN)
# Out:
# True Positives = 25 , False Positives = 2 , True Negatives = 61 , False Negatives = 12

# %%
# Calculating Accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.86

# %%
# Calculating Error Rate
error_rate = 1 - accuracy
print("Error Rate:", error_rate)
# Out:
# Error Rate: 0.14

# %%
# Calculating Precision
precision = precision_score(y_test, y_pred)
print("Precision:", precision)
# Out:
# Precision: 0.9259259259259259

# %%
# Calculating Recall
recall = recall_score(y_test, y_pred)
print("Recall:", recall)
# Out:
# Recall: 0.6756756756756757

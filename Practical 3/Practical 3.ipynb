# %% [markdown]
# # Practical No.3 (Question 1)

# %%
#IMPORTING LIBRARIES
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\MMANTC-MC-03\AppData\Local\Temp\ipykernel_7012\3256497564.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#LOADING DATASET
df = pd.read_csv("income.csv")

# %%
df
# Out:
#                 Name  Age  Income
# 0       Shane Willis   49   29552
# 1      Alexa Walters   32   63507
# 2       Colson Trejo   38   48746
# 3      Rosalyn Logan   42   52392
# 4     Rocco Caldwell   79   36283
# ..               ...  ...     ...
# 96        Theo Rojas   55   76157
# 97   Adaline Rodgers   79   40923
# 98   Mathias Nielsen   34   57345
# 99   Adelaide Dawson   54   75998
# 100  Khizar Karawita   87   16515
#
# [101 rows x 3 columns]

# %%
df.describe()
# Out:
#               Age        Income
# count  101.000000    101.000000
# mean    50.792079  57699.693069
# std     19.358883  22272.705811
# min     20.000000  16515.000000
# 25%     32.000000  38123.000000
# 50%     52.000000  54714.000000
# 75%     68.000000  78441.000000
# max     87.000000  98821.000000

# %%
#GROUPING AGE AND STORING IN A VARIBALE
grouped_data = df.groupby('Age')

# %%
#PRINTING THE VARIABLE BY ITERATION
for age, group in grouped_data:
    print("Age:", age)
    print(group)
# Out:
# Age: 20
#                   Name  Age  Income
# 40           Hugh Howe   20   81459
# 55     Lylah Jaramillo   20   25982
# 75    Paisleigh Rangel   20   89414
# 76        Saint Hansen   20   25520
# 80  Muhammad Jefferson   20   74330
# Age: 21
#                Name  Age  Income
# 57  Emmeline Dawson   21   33056
# 58      Iker Carter   21   64382
# Age: 23
#            Name  Age  Income
# 23  Winter Mann   23   39540
# Age: 24
#                 Name  Age  Income
# 38    Matias Sweeney   24   31173
# 41  Persephone Simon   24   33330
# 63    Delilah Person   24   61991
# 77       Hope Morris   24   63539
# Age: 26
#                Name  Age  Income
# 45      Reina Johns   26   53273
# 54  Genesis Houston   26   30377
# Age: 27
#                 Name  Age  Income
# 8   Guillermo Greene   27   59609
# 10       Bode Monroe   27   40690
# 13     Raina Dejesus   27   34754
# Age: 28
#               Name  Age  Income
# 14      Rio Sierra   28   58755
# 26  Oakley Simpson   28   32648
# ...

# %%
#CALCULATING SUMMARY STATISTICS FOR THE 'INCOME' VARIABLE WITHIN EACH GROUP OF THE DATAFRAMEGROUPBY OBJECT GROUPED_DATA.
summary_stats = grouped_data.describe()

# %%
summary_stats
# Out:
#     Income                                                                    \
#      count          mean           std      min       25%      50%       75%
# Age
# 20     5.0  59341.000000  31124.525282  25520.0  25982.00  74330.0  81459.00
# 21     2.0  48719.000000  22150.827027  33056.0  40887.50  48719.0  56550.50
# 23     1.0  39540.000000           NaN  39540.0  39540.00  39540.0  39540.00
# 24     4.0  47508.250000  17650.289504  31173.0  32790.75  47660.5  62378.00
# 26     2.0  41825.000000  16189.916862  30377.0  36101.00  41825.0  47549.00
# 27     3.0  45017.666667  12980.342073  34754.0  37722.00  40690.0  50149.50
# 28     4.0  46376.500000  16107.502858  32291.0  32558.75  45701.5  59519.25
# 29     1.0  59178.000000           NaN  59178.0  59178.00  59178.0  59178.00
# 31     1.0  48582.000000           NaN  48582.0  48582.00  48582.0  48582.00
# 32     3.0  76030.000000  17084.271919  63507.0  66299.00  69091.0  82291.50
# ...

# %% [markdown]
# # Practical No.3 (Question 2)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df_iris = pd.read_csv('Iris.csv')

# %%
df_iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df_iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
setosa = df_iris[df_iris.iloc[:, -1] == 'Iris-setosa']

# %%
setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
versicolor = df_iris[df_iris.iloc[:, -1] == 'Iris-versicolor']

# %%
versicolor
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50   51            7.0           3.2            4.7           1.4
# 51   52            6.4           3.2            4.5           1.5
# 52   53            6.9           3.1            4.9           1.5
# 53   54            5.5           2.3            4.0           1.3
# 54   55            6.5           2.8            4.6           1.5
# 55   56            5.7           2.8            4.5           1.3
# 56   57            6.3           3.3            4.7           1.6
# 57   58            4.9           2.4            3.3           1.0
# 58   59            6.6           2.9            4.6           1.3
# 59   60            5.2           2.7            3.9           1.4
# 60   61            5.0           2.0            3.5           1.0
# 61   62            5.9           3.0            4.2           1.5
# 62   63            6.0           2.2            4.0           1.0
# ...

# %%
virginica = df_iris[df_iris.iloc[ : , -1] == 'Iris-virginica']

# %%
virginica
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...
